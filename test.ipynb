# %%
class Service:
    def __init__(self, local_initial_slot, number_slots, band, service_id):
        self.local_initial_slot = local_initial_slot
        self.number_slots = number_slots
        self.band = band
        self.service_id = service_id


class SpectrumAllocator:
    def __init__(self):
        # Band base frequencies in Hz (example values)
        self.band_frequencies = {
            'C': {'start': 191.7e12, 'end': 196.0e12},
            'L': {'start': 186.0e12, 'end': 191.7e12}
        }
        self.channel_width = 12.5  # GHz

    def print_slot_frequencies_for_band(self, band: str):
        """
        Print the start and end frequencies for all slots in the specified band.
        
        Args:
            band: Band identifier (e.g., 'C' or 'L')
        """
        if band not in self.band_frequencies:
            print(f"Band '{band}' not found in band frequencies.")
            return
        
        band_start = self.band_frequencies[band]['start']  # in Hz
        band_end = self.band_frequencies[band]['end']      # in Hz
        slot_width_hz = self.channel_width * 1e9           # GHz to Hz
        
        # Calculate number of slots in the band
        num_slots = int((band_end - band_start) / slot_width_hz)
        print(f"Band '{band}' has {num_slots} slots.")
        
        for i in range(num_slots):
            slot_start_freq = band_start + i * slot_width_hz
            slot_end_freq = slot_start_freq + slot_width_hz
            # Print in THz for readability
            print(f"Slot {i}: Start = {slot_start_freq / 1e12:.6f} THz, End = {slot_end_freq / 1e12:.6f} THz")


    def _calculate_center_frequency(self, service: Service) -> float:
        """
        Calculate center frequency using local slots considering slot center offset.
        """
        local_start_slot = service.local_initial_slot
        local_end_slot = local_start_slot + service.number_slots - 1
        
        # Compute local center slot index (fractional)
        local_center_slot = (local_start_slot + local_end_slot) / 2.0
        print("local_center_slot",local_center_slot)
        
        band_base_frequency = self.band_frequencies[service.band]['start']
        slot_width_thz = self.channel_width * 1e-3  # Convert GHz to THz
        
        # Add half slot width offset to get center frequency within slot 
        center_freq = band_base_frequency + (local_center_slot + 0.5) * slot_width_thz * 1e12  # in Hz
        
        band_end_frequency = self.band_frequencies[service.band]['end']
        if not (band_base_frequency <= center_freq <= band_end_frequency):
            self.logger.warning(
                f"Service {service.service_id} center frequency {center_freq/1e12:.3f} THz "
                f"outside band {service.band} range "
                f"[{band_base_frequency/1e12:.3f}, {band_end_frequency/1e12:.3f}] THz"
            )
        
        return center_freq



# Create a dummy service object
dummy_service = Service(local_initial_slot=0, number_slots=3, band='C', service_id='svc1')

# Instantiate allocator and compute center frequency
allocator = SpectrumAllocator()
center_frequency = allocator._calculate_center_frequency(dummy_service)

print(f"Center frequency for the service '{dummy_service.service_id}': {center_frequency/1e12:.6f} THz")
# Out:
# local_center_slot 1.0
# Center frequency for the service 'svc1': 191.718750 THz

# %%
allocator = SpectrumAllocator()
allocator.print_slot_frequencies_for_band('C')
# Out:
# Band 'C' has 344 slots.
# Slot 0: Start = 191.700000 THz, End = 191.712500 THz
# Slot 1: Start = 191.712500 THz, End = 191.725000 THz
# Slot 2: Start = 191.725000 THz, End = 191.737500 THz
# Slot 3: Start = 191.737500 THz, End = 191.750000 THz
# Slot 4: Start = 191.750000 THz, End = 191.762500 THz
# Slot 5: Start = 191.762500 THz, End = 191.775000 THz
# Slot 6: Start = 191.775000 THz, End = 191.787500 THz
# Slot 7: Start = 191.787500 THz, End = 191.800000 THz
# Slot 8: Start = 191.800000 THz, End = 191.812500 THz
# Slot 9: Start = 191.812500 THz, End = 191.825000 THz
# Slot 10: Start = 191.825000 THz, End = 191.837500 THz
# Slot 11: Start = 191.837500 THz, End = 191.850000 THz
# Slot 12: Start = 191.850000 THz, End = 191.862500 THz
# Slot 13: Start = 191.862500 THz, End = 191.875000 THz
# Slot 14: Start = 191.875000 THz, End = 191.887500 THz
# Slot 15: Start = 191.887500 THz, End = 191.900000 THz
# Slot 16: Start = 191.900000 THz, End = 191.912500 THz
# Slot 17: Start = 191.912500 THz, End = 191.925000 THz
# Slot 18: Start = 191.925000 THz, End = 191.937500 THz
# Slot 19: Start = 191.937500 THz, End = 191.950000 THz
# Slot 20: Start = 191.950000 THz, End = 191.962500 THz
# Slot 21: Start = 191.962500 THz, End = 191.975000 THz
# Slot 22: Start = 191.975000 THz, End = 191.987500 THz
# Slot 23: Start = 191.987500 THz, End = 192.000000 THz
# Slot 24: Start = 192.000000 THz, End = 192.012500 THz
# Slot 25: Start = 192.012500 THz, End = 192.025000 THz
# Slot 26: Start = 192.025000 THz, End = 192.037500 THz
# Slot 27: Start = 192.037500 THz, End = 192.050000 THz
# Slot 28: Start = 192.050000 THz, End = 192.062500 THz
# Slot 29: Start = 192.062500 THz, End = 192.075000 THz
# Slot 30: Start = 192.075000 THz, End = 192.087500 THz
# Slot 31: Start = 192.087500 THz, End = 192.100000 THz
# Slot 32: Start = 192.100000 THz, End = 192.112500 THz
# Slot 33: Start = 192.112500 THz, End = 192.125000 THz
# Slot 34: Start = 192.125000 THz, End = 192.137500 THz
# Slot 35: Start = 192.137500 THz, End = 192.150000 THz
# Slot 36: Start = 192.150000 THz, End = 192.162500 THz
# Slot 37: Start = 192.162500 THz, End = 192.175000 THz
# Slot 38: Start = 192.175000 THz, End = 192.187500 THz
# Slot 39: Start = 192.187500 THz, End = 192.200000 THz
# Slot 40: Start = 192.200000 THz, End = 192.212500 THz
# Slot 41: Start = 192.212500 THz, End = 192.225000 THz
# Slot 42: Start = 192.225000 THz, End = 192.237500 THz
# Slot 43: Start = 192.237500 THz, End = 192.250000 THz
# Slot 44: Start = 192.250000 THz, End = 192.262500 THz
# Slot 45: Start = 192.262500 THz, End = 192.275000 THz
# Slot 46: Start = 192.275000 THz, End = 192.287500 THz
# Slot 47: Start = 192.287500 THz, End = 192.300000 THz
# Slot 48: Start = 192.300000 THz, End = 192.312500 THz
# Slot 49: Start = 192.312500 THz, End = 192.325000 THz
# Slot 50: Start = 192.325000 THz, End = 192.337500 THz
# Slot 51: Start = 192.337500 THz, End = 192.350000 THz
# Slot 52: Start = 192.350000 THz, End = 192.362500 THz
# Slot 53: Start = 192.362500 THz, End = 192.375000 THz
# Slot 54: Start = 192.375000 THz, End = 192.387500 THz
# Slot 55: Start = 192.387500 THz, End = 192.400000 THz
# Slot 56: Start = 192.400000 THz, End = 192.412500 THz
# Slot 57: Start = 192.412500 THz, End = 192.425000 THz
# Slot 58: Start = 192.425000 THz, End = 192.437500 THz
# Slot 59: Start = 192.437500 THz, End = 192.450000 THz
# Slot 60: Start = 192.450000 THz, End = 192.462500 THz
# Slot 61: Start = 192.462500 THz, End = 192.475000 THz
# Slot 62: Start = 192.475000 THz, End = 192.487500 THz
# Slot 63: Start = 192.487500 THz, End = 192.500000 THz
# Slot 64: Start = 192.500000 THz, End = 192.512500 THz
# Slot 65: Start = 192.512500 THz, End = 192.525000 THz
# Slot 66: Start = 192.525000 THz, End = 192.537500 THz
# Slot 67: Start = 192.537500 THz, End = 192.550000 THz
# Slot 68: Start = 192.550000 THz, End = 192.562500 THz
# Slot 69: Start = 192.562500 THz, End = 192.575000 THz
# Slot 70: Start = 192.575000 THz, End = 192.587500 THz
# Slot 71: Start = 192.587500 THz, End = 192.600000 THz
# Slot 72: Start = 192.600000 THz, End = 192.612500 THz
# Slot 73: Start = 192.612500 THz, End = 192.625000 THz
# Slot 74: Start = 192.625000 THz, End = 192.637500 THz
# Slot 75: Start = 192.637500 THz, End = 192.650000 THz
# Slot 76: Start = 192.650000 THz, End = 192.662500 THz
# Slot 77: Start = 192.662500 THz, End = 192.675000 THz
# Slot 78: Start = 192.675000 THz, End = 192.687500 THz
# Slot 79: Start = 192.687500 THz, End = 192.700000 THz
# Slot 80: Start = 192.700000 THz, End = 192.712500 THz
# Slot 81: Start = 192.712500 THz, End = 192.725000 THz
# Slot 82: Start = 192.725000 THz, End = 192.737500 THz
# Slot 83: Start = 192.737500 THz, End = 192.750000 THz
# Slot 84: Start = 192.750000 THz, End = 192.762500 THz
# Slot 85: Start = 192.762500 THz, End = 192.775000 THz
# Slot 86: Start = 192.775000 THz, End = 192.787500 THz
# Slot 87: Start = 192.787500 THz, End = 192.800000 THz
# Slot 88: Start = 192.800000 THz, End = 192.812500 THz
# Slot 89: Start = 192.812500 THz, End = 192.825000 THz
# Slot 90: Start = 192.825000 THz, End = 192.837500 THz
# Slot 91: Start = 192.837500 THz, End = 192.850000 THz
# Slot 92: Start = 192.850000 THz, End = 192.862500 THz
# Slot 93: Start = 192.862500 THz, End = 192.875000 THz
# Slot 94: Start = 192.875000 THz, End = 192.887500 THz
# Slot 95: Start = 192.887500 THz, End = 192.900000 THz
# Slot 96: Start = 192.900000 THz, End = 192.912500 THz
# Slot 97: Start = 192.912500 THz, End = 192.925000 THz
# Slot 98: Start = 192.925000 THz, End = 192.937500 THz
# Slot 99: Start = 192.937500 THz, End = 192.950000 THz
# Slot 100: Start = 192.950000 THz, End = 192.962500 THz
# Slot 101: Start = 192.962500 THz, End = 192.975000 THz
# Slot 102: Start = 192.975000 THz, End = 192.987500 THz
# Slot 103: Start = 192.987500 THz, End = 193.000000 THz
# Slot 104: Start = 193.000000 THz, End = 193.012500 THz
# Slot 105: Start = 193.012500 THz, End = 193.025000 THz
# Slot 106: Start = 193.025000 THz, End = 193.037500 THz
# Slot 107: Start = 193.037500 THz, End = 193.050000 THz
# Slot 108: Start = 193.050000 THz, End = 193.062500 THz
# Slot 109: Start = 193.062500 THz, End = 193.075000 THz
# Slot 110: Start = 193.075000 THz, End = 193.087500 THz
# Slot 111: Start = 193.087500 THz, End = 193.100000 THz
# Slot 112: Start = 193.100000 THz, End = 193.112500 THz
# Slot 113: Start = 193.112500 THz, End = 193.125000 THz
# Slot 114: Start = 193.125000 THz, End = 193.137500 THz
# Slot 115: Start = 193.137500 THz, End = 193.150000 THz
# Slot 116: Start = 193.150000 THz, End = 193.162500 THz
# Slot 117: Start = 193.162500 THz, End = 193.175000 THz
# Slot 118: Start = 193.175000 THz, End = 193.187500 THz
# Slot 119: Start = 193.187500 THz, End = 193.200000 THz
# Slot 120: Start = 193.200000 THz, End = 193.212500 THz
# Slot 121: Start = 193.212500 THz, End = 193.225000 THz
# Slot 122: Start = 193.225000 THz, End = 193.237500 THz
# Slot 123: Start = 193.237500 THz, End = 193.250000 THz
# Slot 124: Start = 193.250000 THz, End = 193.262500 THz
# Slot 125: Start = 193.262500 THz, End = 193.275000 THz
# Slot 126: Start = 193.275000 THz, End = 193.287500 THz
# Slot 127: Start = 193.287500 THz, End = 193.300000 THz
# Slot 128: Start = 193.300000 THz, End = 193.312500 THz
# Slot 129: Start = 193.312500 THz, End = 193.325000 THz
# Slot 130: Start = 193.325000 THz, End = 193.337500 THz
# Slot 131: Start = 193.337500 THz, End = 193.350000 THz
# Slot 132: Start = 193.350000 THz, End = 193.362500 THz
# Slot 133: Start = 193.362500 THz, End = 193.375000 THz
# Slot 134: Start = 193.375000 THz, End = 193.387500 THz
# Slot 135: Start = 193.387500 THz, End = 193.400000 THz
# Slot 136: Start = 193.400000 THz, End = 193.412500 THz
# Slot 137: Start = 193.412500 THz, End = 193.425000 THz
# Slot 138: Start = 193.425000 THz, End = 193.437500 THz
# Slot 139: Start = 193.437500 THz, End = 193.450000 THz
# Slot 140: Start = 193.450000 THz, End = 193.462500 THz
# Slot 141: Start = 193.462500 THz, End = 193.475000 THz
# Slot 142: Start = 193.475000 THz, End = 193.487500 THz
# Slot 143: Start = 193.487500 THz, End = 193.500000 THz
# Slot 144: Start = 193.500000 THz, End = 193.512500 THz
# Slot 145: Start = 193.512500 THz, End = 193.525000 THz
# Slot 146: Start = 193.525000 THz, End = 193.537500 THz
# Slot 147: Start = 193.537500 THz, End = 193.550000 THz
# Slot 148: Start = 193.550000 THz, End = 193.562500 THz
# Slot 149: Start = 193.562500 THz, End = 193.575000 THz
# Slot 150: Start = 193.575000 THz, End = 193.587500 THz
# Slot 151: Start = 193.587500 THz, End = 193.600000 THz
# Slot 152: Start = 193.600000 THz, End = 193.612500 THz
# Slot 153: Start = 193.612500 THz, End = 193.625000 THz
# Slot 154: Start = 193.625000 THz, End = 193.637500 THz
# Slot 155: Start = 193.637500 THz, End = 193.650000 THz
# Slot 156: Start = 193.650000 THz, End = 193.662500 THz
# Slot 157: Start = 193.662500 THz, End = 193.675000 THz
# Slot 158: Start = 193.675000 THz, End = 193.687500 THz
# Slot 159: Start = 193.687500 THz, End = 193.700000 THz
# Slot 160: Start = 193.700000 THz, End = 193.712500 THz
# Slot 161: Start = 193.712500 THz, End = 193.725000 THz
# Slot 162: Start = 193.725000 THz, End = 193.737500 THz
# Slot 163: Start = 193.737500 THz, End = 193.750000 THz
# Slot 164: Start = 193.750000 THz, End = 193.762500 THz
# Slot 165: Start = 193.762500 THz, End = 193.775000 THz
# Slot 166: Start = 193.775000 THz, End = 193.787500 THz
# Slot 167: Start = 193.787500 THz, End = 193.800000 THz
# Slot 168: Start = 193.800000 THz, End = 193.812500 THz
# Slot 169: Start = 193.812500 THz, End = 193.825000 THz
# Slot 170: Start = 193.825000 THz, End = 193.837500 THz
# Slot 171: Start = 193.837500 THz, End = 193.850000 THz
# Slot 172: Start = 193.850000 THz, End = 193.862500 THz
# Slot 173: Start = 193.862500 THz, End = 193.875000 THz
# Slot 174: Start = 193.875000 THz, End = 193.887500 THz
# Slot 175: Start = 193.887500 THz, End = 193.900000 THz
# Slot 176: Start = 193.900000 THz, End = 193.912500 THz
# Slot 177: Start = 193.912500 THz, End = 193.925000 THz
# Slot 178: Start = 193.925000 THz, End = 193.937500 THz
# Slot 179: Start = 193.937500 THz, End = 193.950000 THz
# Slot 180: Start = 193.950000 THz, End = 193.962500 THz
# Slot 181: Start = 193.962500 THz, End = 193.975000 THz
# Slot 182: Start = 193.975000 THz, End = 193.987500 THz
# Slot 183: Start = 193.987500 THz, End = 194.000000 THz
# Slot 184: Start = 194.000000 THz, End = 194.012500 THz
# Slot 185: Start = 194.012500 THz, End = 194.025000 THz
# Slot 186: Start = 194.025000 THz, End = 194.037500 THz
# Slot 187: Start = 194.037500 THz, End = 194.050000 THz
# Slot 188: Start = 194.050000 THz, End = 194.062500 THz
# Slot 189: Start = 194.062500 THz, End = 194.075000 THz
# Slot 190: Start = 194.075000 THz, End = 194.087500 THz
# Slot 191: Start = 194.087500 THz, End = 194.100000 THz
# Slot 192: Start = 194.100000 THz, End = 194.112500 THz
# Slot 193: Start = 194.112500 THz, End = 194.125000 THz
# Slot 194: Start = 194.125000 THz, End = 194.137500 THz
# Slot 195: Start = 194.137500 THz, End = 194.150000 THz
# Slot 196: Start = 194.150000 THz, End = 194.162500 THz
# Slot 197: Start = 194.162500 THz, End = 194.175000 THz
# Slot 198: Start = 194.175000 THz, End = 194.187500 THz
# Slot 199: Start = 194.187500 THz, End = 194.200000 THz
# Slot 200: Start = 194.200000 THz, End = 194.212500 THz
# Slot 201: Start = 194.212500 THz, End = 194.225000 THz
# Slot 202: Start = 194.225000 THz, End = 194.237500 THz
# Slot 203: Start = 194.237500 THz, End = 194.250000 THz
# Slot 204: Start = 194.250000 THz, End = 194.262500 THz
# Slot 205: Start = 194.262500 THz, End = 194.275000 THz
# Slot 206: Start = 194.275000 THz, End = 194.287500 THz
# Slot 207: Start = 194.287500 THz, End = 194.300000 THz
# Slot 208: Start = 194.300000 THz, End = 194.312500 THz
# Slot 209: Start = 194.312500 THz, End = 194.325000 THz
# Slot 210: Start = 194.325000 THz, End = 194.337500 THz
# Slot 211: Start = 194.337500 THz, End = 194.350000 THz
# Slot 212: Start = 194.350000 THz, End = 194.362500 THz
# Slot 213: Start = 194.362500 THz, End = 194.375000 THz
# Slot 214: Start = 194.375000 THz, End = 194.387500 THz
# Slot 215: Start = 194.387500 THz, End = 194.400000 THz
# Slot 216: Start = 194.400000 THz, End = 194.412500 THz
# Slot 217: Start = 194.412500 THz, End = 194.425000 THz
# Slot 218: Start = 194.425000 THz, End = 194.437500 THz
# Slot 219: Start = 194.437500 THz, End = 194.450000 THz
# Slot 220: Start = 194.450000 THz, End = 194.462500 THz
# Slot 221: Start = 194.462500 THz, End = 194.475000 THz
# Slot 222: Start = 194.475000 THz, End = 194.487500 THz
# Slot 223: Start = 194.487500 THz, End = 194.500000 THz
# Slot 224: Start = 194.500000 THz, End = 194.512500 THz
# Slot 225: Start = 194.512500 THz, End = 194.525000 THz
# Slot 226: Start = 194.525000 THz, End = 194.537500 THz
# Slot 227: Start = 194.537500 THz, End = 194.550000 THz
# Slot 228: Start = 194.550000 THz, End = 194.562500 THz
# Slot 229: Start = 194.562500 THz, End = 194.575000 THz
# Slot 230: Start = 194.575000 THz, End = 194.587500 THz
# Slot 231: Start = 194.587500 THz, End = 194.600000 THz
# Slot 232: Start = 194.600000 THz, End = 194.612500 THz
# Slot 233: Start = 194.612500 THz, End = 194.625000 THz
# Slot 234: Start = 194.625000 THz, End = 194.637500 THz
# Slot 235: Start = 194.637500 THz, End = 194.650000 THz
# Slot 236: Start = 194.650000 THz, End = 194.662500 THz
# Slot 237: Start = 194.662500 THz, End = 194.675000 THz
# Slot 238: Start = 194.675000 THz, End = 194.687500 THz
# Slot 239: Start = 194.687500 THz, End = 194.700000 THz
# Slot 240: Start = 194.700000 THz, End = 194.712500 THz
# Slot 241: Start = 194.712500 THz, End = 194.725000 THz
# Slot 242: Start = 194.725000 THz, End = 194.737500 THz
# Slot 243: Start = 194.737500 THz, End = 194.750000 THz
# Slot 244: Start = 194.750000 THz, End = 194.762500 THz
# Slot 245: Start = 194.762500 THz, End = 194.775000 THz
# Slot 246: Start = 194.775000 THz, End = 194.787500 THz
# Slot 247: Start = 194.787500 THz, End = 194.800000 THz
# Slot 248: Start = 194.800000 THz, End = 194.812500 THz
# Slot 249: Start = 194.812500 THz, End = 194.825000 THz
# Slot 250: Start = 194.825000 THz, End = 194.837500 THz
# Slot 251: Start = 194.837500 THz, End = 194.850000 THz
# Slot 252: Start = 194.850000 THz, End = 194.862500 THz
# Slot 253: Start = 194.862500 THz, End = 194.875000 THz
# Slot 254: Start = 194.875000 THz, End = 194.887500 THz
# Slot 255: Start = 194.887500 THz, End = 194.900000 THz
# Slot 256: Start = 194.900000 THz, End = 194.912500 THz
# Slot 257: Start = 194.912500 THz, End = 194.925000 THz
# Slot 258: Start = 194.925000 THz, End = 194.937500 THz
# Slot 259: Start = 194.937500 THz, End = 194.950000 THz
# Slot 260: Start = 194.950000 THz, End = 194.962500 THz
# Slot 261: Start = 194.962500 THz, End = 194.975000 THz
# Slot 262: Start = 194.975000 THz, End = 194.987500 THz
# Slot 263: Start = 194.987500 THz, End = 195.000000 THz
# Slot 264: Start = 195.000000 THz, End = 195.012500 THz
# Slot 265: Start = 195.012500 THz, End = 195.025000 THz
# Slot 266: Start = 195.025000 THz, End = 195.037500 THz
# Slot 267: Start = 195.037500 THz, End = 195.050000 THz
# Slot 268: Start = 195.050000 THz, End = 195.062500 THz
# Slot 269: Start = 195.062500 THz, End = 195.075000 THz
# Slot 270: Start = 195.075000 THz, End = 195.087500 THz
# Slot 271: Start = 195.087500 THz, End = 195.100000 THz
# Slot 272: Start = 195.100000 THz, End = 195.112500 THz
# Slot 273: Start = 195.112500 THz, End = 195.125000 THz
# Slot 274: Start = 195.125000 THz, End = 195.137500 THz
# Slot 275: Start = 195.137500 THz, End = 195.150000 THz
# Slot 276: Start = 195.150000 THz, End = 195.162500 THz
# Slot 277: Start = 195.162500 THz, End = 195.175000 THz
# Slot 278: Start = 195.175000 THz, End = 195.187500 THz
# Slot 279: Start = 195.187500 THz, End = 195.200000 THz
# Slot 280: Start = 195.200000 THz, End = 195.212500 THz
# Slot 281: Start = 195.212500 THz, End = 195.225000 THz
# Slot 282: Start = 195.225000 THz, End = 195.237500 THz
# Slot 283: Start = 195.237500 THz, End = 195.250000 THz
# Slot 284: Start = 195.250000 THz, End = 195.262500 THz
# Slot 285: Start = 195.262500 THz, End = 195.275000 THz
# Slot 286: Start = 195.275000 THz, End = 195.287500 THz
# Slot 287: Start = 195.287500 THz, End = 195.300000 THz
# Slot 288: Start = 195.300000 THz, End = 195.312500 THz
# Slot 289: Start = 195.312500 THz, End = 195.325000 THz
# Slot 290: Start = 195.325000 THz, End = 195.337500 THz
# Slot 291: Start = 195.337500 THz, End = 195.350000 THz
# Slot 292: Start = 195.350000 THz, End = 195.362500 THz
# Slot 293: Start = 195.362500 THz, End = 195.375000 THz
# Slot 294: Start = 195.375000 THz, End = 195.387500 THz
# Slot 295: Start = 195.387500 THz, End = 195.400000 THz
# Slot 296: Start = 195.400000 THz, End = 195.412500 THz
# Slot 297: Start = 195.412500 THz, End = 195.425000 THz
# Slot 298: Start = 195.425000 THz, End = 195.437500 THz
# Slot 299: Start = 195.437500 THz, End = 195.450000 THz
# Slot 300: Start = 195.450000 THz, End = 195.462500 THz
# Slot 301: Start = 195.462500 THz, End = 195.475000 THz
# Slot 302: Start = 195.475000 THz, End = 195.487500 THz
# Slot 303: Start = 195.487500 THz, End = 195.500000 THz
# Slot 304: Start = 195.500000 THz, End = 195.512500 THz
# Slot 305: Start = 195.512500 THz, End = 195.525000 THz
# Slot 306: Start = 195.525000 THz, End = 195.537500 THz
# Slot 307: Start = 195.537500 THz, End = 195.550000 THz
# Slot 308: Start = 195.550000 THz, End = 195.562500 THz
# Slot 309: Start = 195.562500 THz, End = 195.575000 THz
# Slot 310: Start = 195.575000 THz, End = 195.587500 THz
# Slot 311: Start = 195.587500 THz, End = 195.600000 THz
# Slot 312: Start = 195.600000 THz, End = 195.612500 THz
# Slot 313: Start = 195.612500 THz, End = 195.625000 THz
# Slot 314: Start = 195.625000 THz, End = 195.637500 THz
# Slot 315: Start = 195.637500 THz, End = 195.650000 THz
# Slot 316: Start = 195.650000 THz, End = 195.662500 THz
# Slot 317: Start = 195.662500 THz, End = 195.675000 THz
# Slot 318: Start = 195.675000 THz, End = 195.687500 THz
# Slot 319: Start = 195.687500 THz, End = 195.700000 THz
# Slot 320: Start = 195.700000 THz, End = 195.712500 THz
# Slot 321: Start = 195.712500 THz, End = 195.725000 THz
# Slot 322: Start = 195.725000 THz, End = 195.737500 THz
# Slot 323: Start = 195.737500 THz, End = 195.750000 THz
# Slot 324: Start = 195.750000 THz, End = 195.762500 THz
# Slot 325: Start = 195.762500 THz, End = 195.775000 THz
# Slot 326: Start = 195.775000 THz, End = 195.787500 THz
# Slot 327: Start = 195.787500 THz, End = 195.800000 THz
# Slot 328: Start = 195.800000 THz, End = 195.812500 THz
# Slot 329: Start = 195.812500 THz, End = 195.825000 THz
# Slot 330: Start = 195.825000 THz, End = 195.837500 THz
# Slot 331: Start = 195.837500 THz, End = 195.850000 THz
# Slot 332: Start = 195.850000 THz, End = 195.862500 THz
# Slot 333: Start = 195.862500 THz, End = 195.875000 THz
# Slot 334: Start = 195.875000 THz, End = 195.887500 THz
# Slot 335: Start = 195.887500 THz, End = 195.900000 THz
# Slot 336: Start = 195.900000 THz, End = 195.912500 THz
# Slot 337: Start = 195.912500 THz, End = 195.925000 THz
# Slot 338: Start = 195.925000 THz, End = 195.937500 THz
# Slot 339: Start = 195.937500 THz, End = 195.950000 THz
# Slot 340: Start = 195.950000 THz, End = 195.962500 THz
# Slot 341: Start = 195.962500 THz, End = 195.975000 THz
# Slot 342: Start = 195.975000 THz, End = 195.987500 THz
# Slot 343: Start = 195.987500 THz, End = 196.000000 THz
